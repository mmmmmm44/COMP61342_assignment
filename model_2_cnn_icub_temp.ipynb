# %% [markdown]
# Using pre-trained object detection models from pytorch
# Fine-tuned on the icub dataset
#
# Reference: https://www.kaggle.com/code/yerramvarun/fine-tuning-faster-rcnn-using-pytorch

# %%
from pathlib import Path

images_dir = Path('dataset/icub/Images')
annotations_dir = Path('dataset/icub/Annotations_refined')
manual_subset_dir = Path('dataset/icub/Images_subset_manual')
manual_annotations_dir = Path('dataset/icub/Annotations_manual')

# %%
import os
os.listdir(annotations_dir)
# Out:
# ['wallet',
#  'sunglasses',
#  'pencilcase',
#  'remote',
#  'squeezer',
#  'sodabottle',
#  'glass',
#  'book',
#  'mouse',
#  'mug',
#  'soapdispenser',
#  'ringbinder',
#  'README.md',
#  'hairclip',
#  'hairbrush',
#  'sprayer',
#  'perfume',
#  'flower',
#  'bodylotion',
#  'ovenglove',
#  'cellphone']

# %%
import torch
import os
from lxml import etree

from torchvision.io import read_image
from torchvision.transforms import v2

class ICubDataset(torch.utils.data.Dataset):
    def __init__(self, images_dir, annotations_dir, manual_subset_dir, manual_annotations_dir, transforms):
        self.images_dir = images_dir
        self.annotations_dir = annotations_dir
        self.manual_subset_dir = manual_subset_dir
        self.manual_annotations_dir = manual_annotations_dir
        self.transforms = transforms

        self.train_indices = []
        self.test_indices = []

        # get all categories = walk under the annotations directory
        self.categories = sorted([x.name for x in Path.iterdir(annotations_dir) if x.is_dir()])
        self.sub_categories = []
        for cat in self.categories:
            self.sub_categories.append(sorted([x.name for x in Path.iterdir(Path(annotations_dir, cat)) if x.is_dir()]))
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs_path = []
        self.annotations_path = []

        for cat, sub_cats in zip(self.categories, self.sub_categories):
            for sub_cat in sub_cats:
                days_dir = [x for x in Path.iterdir(Path(images_dir, cat, sub_cat, 'MIX')) if x.is_dir()]
                for day_dir in days_dir:
                    # get all images' paths and find all files end with .jpg
                    images = sorted(Path.iterdir(Path(day_dir, 'left')))
                    images = [x for x in images if x.name.endswith('.jpg')]

                    # get all annotations (xml file paths)
                    annotations = sorted(Path.iterdir(Path(annotations_dir, cat, sub_cat, 'MIX', day_dir.name, 'left')))

                    annotations_to_be_removed = []

                    # check every annotations to find bboxes with negative values
                    # remove the annotation and the corresponding image if there is a negative value
                    for i, annotation in enumerate(annotations):
                        tree = etree.parse(str(annotation))
                        root = tree.getroot()
                        for obj in root.iter('object'):
                            bndbox = obj.find('bndbox')

                            x_min = int(bndbox.find('xmin').text)
                            y_min = int(bndbox.find('ymin').text)
                            x_max = int(bndbox.find('xmax').text)
                            y_max = int(bndbox.find('ymax').text)

                            # check if the bbox is valid
                            if ((x_min < 0) or (y_min < 0) or (x_max < 0) or (y_max < 0)):
                                # remove the annotation from the list
                                annotations_to_be_removed.append(annotation)

                    # remove the annotations from the list
                    for annotation in annotations_to_be_removed:
                        print(f"Removing {annotation} from annotations")
                        annotations.remove(annotation)
                        # remove the corresponding image from the list
                        image_name = annotation.name[:-4] + '.jpg'
                        image_path = Path.joinpath(images[0].parent, image_name)
                        if image_path in images:
                            print(f"Removing {image_path} from images")
                            images.remove(image_path)


                    # if both have equal number of files -> normal
                    # else: compare the two lists and find the difference
                    if len(images) != len(annotations):
                        image_set = set([x.name[:-4] for x in images])
                        annotation_set = set([x.name[:-4] for x in annotations])
                        diff = image_set ^ annotation_set

                        # for every difference entry, check whether it is missin in image or annotation set
                        for entry in diff:
                            if entry in image_set:      # there is an image but no annotation -> remove the image
                                # remove the image from the list
                                print(f"Removing {Path.joinpath(images[0].parent, entry + '.jpg')} from images")
                                images.remove(Path.joinpath(images[0].parent, entry + '.jpg'))

                            else:                       # there is an annotation but no image -> remove the annotation
                                # remove the annotation from the list
                                print(f"Removing {Path.joinpath(annotations[0].parent, entry + '.xml')} from annotations")
                                annotations.remove(Path.joinpath(annotations[0].parent, entry + '.xml'))
                                
            
                    # for every images, check whether it's in the manual subset
                    # if yes, store the index of the image
                    for i, img_path in enumerate(images):
                        if self.manual_subset_dir.joinpath('/'.join(img_path.parts[3:])).exists():
                            self.test_indices.append(i + len(self.imgs_path))

                            # replace the annotation path to the manual annotation path
                            annotation_path = self.manual_annotations_dir.joinpath('/'.join(img_path.parts[3:])).with_suffix('.xml')
                            if annotation_path.exists():
                                annotations[i] = annotation_path
                        else:   
                            self.train_indices.append(i + len(self.imgs_path))



                    assert len(images) == len(annotations), f"Number of images and annotations do not match in {cat}/{sub_cat}/{day_dir.name}. " + \
                        f"Number of images: {len(images)}, Number of annotations: {len(annotations)}. Difference in set: {set([x.name[:-4] for x in images]) ^ set([x.name[:-4] for x in annotations])}"

                    self.imgs_path += images
                    self.annotations_path += annotations

        self.labels = ['background']        # first label is reserved for background
        for cats in self.categories:
            self.labels.append(cats)

    def __getitem__(self, idx):
        img_path = self.imgs_path[idx]
        annotation_path = self.annotations_path[idx]

        # load image
        image = read_image(str(img_path))
        # load annotation
        tree = etree.parse(str(annotation_path))
        root = tree.getroot()
        # get the bbox of the object
        bbox = []
        label = ''
        for obj in root.iter('object'):
            # get the label of the object
            label = obj.find('category').text

            bndbox = obj.find('bndbox')
            bbox.append([int(bndbox.find('xmin').text),
                         int(bndbox.find('ymin').text),
                         int(bndbox.find('xmax').text),
                         int(bndbox.find('ymax').text)])
            
        # pre-processing
        # reduce the size of the image to 224x224
        # the dimension of the image is represented as (channel, height, width)
        # image_resized = v2.Resize((224, 224))(image)
        # # convert the bbox to the resized image
        # bbox_resized = []
        # for box in bbox:
        #     xmin = int(box[0] * 224.0 / image.shape[2])
        #     ymin = int(box[1] * 224.0 / image.shape[1])
        #     xmax = int(box[2] * 224.0 / image.shape[2])
        #     ymax = int(box[3] * 224.0 / image.shape[1])
        #     bbox_resized.append([xmin, ymin, xmax, ymax])

        # print('Image path:', img_path)
        # print('Annotation path:', annotation_path)
        # print('BBox:', bbox)
        # print('BBox_resized:', bbox_resized)

        target = {}
        target['boxes'] = torch.tensor(bbox, dtype=torch.float32)
        target['labels'] = torch.tensor([self.labels.index(label)], dtype=torch.int64)
        target['area'] = torch.tensor([(box[2] - box[0]) * (box[3] - box[1]) for box in bbox], dtype=torch.float32)
        target['iscrowd'] = torch.tensor([0], dtype=torch.int64)
        target['image_id'] = torch.tensor([idx])

        if self.transforms:
            image_resized, target = self.transforms(image, target)
        else:
            image_resized = image
        
        return image_resized, target
    
    def get_details_from_id(self, idx):
        img_path = self.imgs_path[idx]
        annotation_path = self.annotations_path[idx]

        # load image
        image = read_image(str(img_path))
        # load annotation
        tree = etree.parse(str(annotation_path))
        root = tree.getroot()
        # get the bbox of the object
        bbox = []
        label = ''
        for obj in root.iter('object'):
            # get the label of the object
            label = obj.find('category').text

            bndbox = obj.find('bndbox')
            bbox.append([int(bndbox.find('xmin').text),
                         int(bndbox.find('ymin').text),
                         int(bndbox.find('xmax').text),
                         int(bndbox.find('ymax').text)])
        
        return img_path, annotation_path, image, bbox, label
    
    def __len__(self):
        return len(self.imgs_path)

# %%
# Since v0.15.0 torchvision provides new Transforms API to easily write data augmentation pipelines for Object Detection and Segmentation tasks.
# Let’s write some helper functions for data augmentation / transformation:

from torchvision.transforms import v2 as T

def get_transform(train):
    transforms = []
    # if train:
    #     transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %%
# check dataset
dataset = ICubDataset(images_dir, annotations_dir, manual_subset_dir, manual_annotations_dir, get_transform(train=False))
print('length of dataset = ', len(dataset), '\n')

# getting the image and target for a test index.
img, target = dataset[96339]
print(img.shape, '\n',target)
# Out:
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day1/left/00002946.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day1/left/00002946.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day1/left/00003198.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day1/left/00003198.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day1/left/00003258.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day1/left/00003258.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day1/left/00003280.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day1/left/00003280.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day2/left/00007918.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day2/left/00007918.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day2/left/00007919.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day2/left/00007919.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion1/MIX/day2/left/00007920.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion1/MIX/day2/left/00007920.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion10/MIX/day1/left/00006981.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion10/MIX/day1/left/00006981.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion10/MIX/day1/left/00007008.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion10/MIX/day1/left/00007008.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion10/MIX/day1/left/00007314.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion10/MIX/day1/left/00007314.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion10/MIX/day2/left/00005784.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion10/MIX/day2/left/00005784.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion2/MIX/day1/left/00004268.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion2/MIX/day1/left/00004268.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion4/MIX/day1/left/00005776.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion4/MIX/day1/left/00005776.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion4/MIX/day1/left/00005801.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion4/MIX/day1/left/00005801.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion4/MIX/day1/left/00005947.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion4/MIX/day1/left/00005947.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion4/MIX/day1/left/00005997.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion4/MIX/day1/left/00005997.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion5/MIX/day1/left/00003942.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion5/MIX/day1/left/00003942.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion5/MIX/day1/left/00003946.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion5/MIX/day1/left/00003946.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion5/MIX/day1/left/00004056.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion5/MIX/day1/left/00004056.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion5/MIX/day1/left/00004078.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion5/MIX/day1/left/00004078.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion6/MIX/day1/left/00005150.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion6/MIX/day1/left/00005150.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion6/MIX/day2/left/00002016.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion6/MIX/day2/left/00002016.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion7/MIX/day1/left/00006072.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion7/MIX/day1/left/00006072.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion7/MIX/day1/left/00006084.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion7/MIX/day1/left/00006084.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion7/MIX/day1/left/00006196.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion7/MIX/day1/left/00006196.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion8/MIX/day1/left/00001999.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion8/MIX/day1/left/00001999.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion8/MIX/day1/left/00002041.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion8/MIX/day1/left/00002041.jpg from images
# Removing dataset/icub/Annotations_refined/bodylotion/bodylotion8/MIX/day2/left/00008007.xml from annotations
# Removing dataset/icub/Images/bodylotion/bodylotion8/MIX/day2/left/00008007.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006187.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006187.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006188.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006188.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006189.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006189.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006190.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006190.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006439.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006439.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006440.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006440.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006441.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006441.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day6/left/00006442.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day6/left/00006442.jpg from images
# Removing dataset/icub/Annotations_refined/book/book1/MIX/day5/left/00006265.xml from annotations
# Removing dataset/icub/Images/book/book1/MIX/day5/left/00006265.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000810.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000810.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000811.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000811.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000812.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000812.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000898.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000898.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000980.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000980.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day6/left/00000981.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day6/left/00000981.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005398.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005398.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005399.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005399.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005400.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005400.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005568.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005568.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005660.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005660.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005661.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005661.jpg from images
# Removing dataset/icub/Annotations_refined/book/book10/MIX/day5/left/00005662.xml from annotations
# Removing dataset/icub/Images/book/book10/MIX/day5/left/00005662.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00004937.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00004937.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005007.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005007.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005071.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005071.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005072.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005072.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005162.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005162.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005163.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005163.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005164.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005164.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day6/left/00005165.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day6/left/00005165.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day5/left/00000751.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day5/left/00000751.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day5/left/00000752.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day5/left/00000752.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day5/left/00000847.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day5/left/00000847.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day5/left/00000945.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day5/left/00000945.jpg from images
# Removing dataset/icub/Annotations_refined/book/book2/MIX/day5/left/00000956.xml from annotations
# Removing dataset/icub/Images/book/book2/MIX/day5/left/00000956.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00003833.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00003833.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00003978.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00003978.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00004095.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00004095.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00004096.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00004096.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00004097.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00004097.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day6/left/00004099.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day6/left/00004099.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day5/left/00002431.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day5/left/00002431.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day5/left/00002668.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day5/left/00002668.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day5/left/00002669.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day5/left/00002669.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day5/left/00002670.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day5/left/00002670.jpg from images
# Removing dataset/icub/Annotations_refined/book/book3/MIX/day5/left/00002672.xml from annotations
# Removing dataset/icub/Images/book/book3/MIX/day5/left/00002672.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002669.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002669.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002689.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002689.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002702.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002702.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002703.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002703.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002798.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002798.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002799.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002799.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00002800.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00002800.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00003022.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00003022.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00003023.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00003023.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day6/left/00003024.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day6/left/00003024.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day5/left/00004535.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day5/left/00004535.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day5/left/00004623.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day5/left/00004623.jpg from images
# Removing dataset/icub/Annotations_refined/book/book4/MIX/day5/left/00004681.xml from annotations
# Removing dataset/icub/Images/book/book4/MIX/day5/left/00004681.jpg from images
# Removing dataset/icub/Annotations_refined/book/book5/MIX/day6/left/00001730.xml from annotations
# Removing dataset/icub/Images/book/book5/MIX/day6/left/00001730.jpg from images
# Removing dataset/icub/Annotations_refined/book/book5/MIX/day6/left/00001732.xml from annotations
# Removing dataset/icub/Images/book/book5/MIX/day6/left/00001732.jpg from images
# Removing dataset/icub/Annotations_refined/book/book5/MIX/day6/left/00001733.xml from annotations
# Removing dataset/icub/Images/book/book5/MIX/day6/left/00001733.jpg from images
# Removing dataset/icub/Annotations_refined/book/book6/MIX/day6/left/00006275.xml from annotations
# Removing dataset/icub/Images/book/book6/MIX/day6/left/00006275.jpg from images
# Removing dataset/icub/Annotations_refined/book/book6/MIX/day6/left/00006361.xml from annotations
# Removing dataset/icub/Images/book/book6/MIX/day6/left/00006361.jpg from images
# Removing dataset/icub/Annotations_refined/book/book6/MIX/day5/left/00000898.xml from annotations
# Removing dataset/icub/Images/book/book6/MIX/day5/left/00000898.jpg from images
# Removing dataset/icub/Annotations_refined/book/book6/MIX/day5/left/00000901.xml from annotations
# Removing dataset/icub/Images/book/book6/MIX/day5/left/00000901.jpg from images
# Removing dataset/icub/Annotations_refined/book/book7/MIX/day6/left/00004947.xml from annotations
# Removing dataset/icub/Images/book/book7/MIX/day6/left/00004947.jpg from images
# Removing dataset/icub/Annotations_refined/book/book7/MIX/day6/left/00005166.xml from annotations
# Removing dataset/icub/Images/book/book7/MIX/day6/left/00005166.jpg from images
# Removing dataset/icub/Annotations_refined/book/book7/MIX/day6/left/00005167.xml from annotations
# Removing dataset/icub/Images/book/book7/MIX/day6/left/00005167.jpg from images
# Removing dataset/icub/Annotations_refined/book/book7/MIX/day6/left/00005177.xml from annotations
# Removing dataset/icub/Images/book/book7/MIX/day6/left/00005177.jpg from images
jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007568.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007568.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007576.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007576.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007577.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007577.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007578.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007578.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007664.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007664.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day8/left/00007665.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day8/left/00007665.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day7/left/00006655.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day7/left/00006655.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day7/left/00006887.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day7/left/00006887.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower10/MIX/day7/left/00006888.xml from annotations
# Removing dataset/icub/Images/flower/flower10/MIX/day7/left/00006888.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower2/MIX/day7/left/00003403.xml from annotations
# Removing dataset/icub/Images/flower/flower2/MIX/day7/left/00003403.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower2/MIX/day7/left/00003404.xml from annotations
# Removing dataset/icub/Images/flower/flower2/MIX/day7/left/00003404.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower2/MIX/day7/left/00003405.xml from annotations
# Removing dataset/icub/Images/flower/flower2/MIX/day7/left/00003405.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower2/MIX/day7/left/00003523.xml from annotations
# Removing dataset/icub/Images/flower/flower2/MIX/day7/left/00003523.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004457.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004457.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004482.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004482.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004614.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004614.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004616.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004616.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004723.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004723.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004724.xml from annotations
# Removing dataset/icub/Images/flower/flower3/MIX/day7/left/00004724.jpg from images
# Removing dataset/icub/Annotations_refined/flower/flower3/MIX/day7/left/00004725.xml from annotations
# ...
# Removing dataset/icub/Annotations_refined/sunglasses/sunglasses9/MIX/day4/left/00004516.xml from annotations
# Removing dataset/icub/Images/sunglasses/sunglasses9/MIX/day4/left/00004516.jpg from images
# Removing dataset/icub/Annotations_refined/sunglasses/sunglasses9/MIX/day4/left/00004677.xml from annotations
# Removing dataset/icub/Images/sunglasses/sunglasses9/MIX/day4/left/00004677.jpg from images
# Removing dataset/icub/Annotations_refined/sunglasses/sunglasses9/MIX/day3/left/00004402.xml from annotations
# Removing dataset/icub/Images/sunglasses/sunglasses9/MIX/day3/left/00004402.jpg from images
# Removing dataset/icub/Annotations_refined/sunglasses/sunglasses9/MIX/day3/left/00004407.xml from annotations
jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day4/left/00003605.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day4/left/00003605.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day4/left/00003654.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day4/left/00003654.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day4/left/00003655.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day4/left/00003655.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day4/left/00003766.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day4/left/00003766.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day4/left/00003767.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day4/left/00003767.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day3/left/00005923.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day3/left/00005923.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day3/left/00005924.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day3/left/00005924.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet8/MIX/day3/left/00005973.xml from annotations
# Removing dataset/icub/Images/wallet/wallet8/MIX/day3/left/00005973.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day4/left/00004676.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day4/left/00004676.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day4/left/00004750.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day4/left/00004750.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day4/left/00004799.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day4/left/00004799.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day3/left/00004007.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day3/left/00004007.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day3/left/00004008.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day3/left/00004008.jpg from images
# Removing dataset/icub/Annotations_refined/wallet/wallet9/MIX/day3/left/00004144.xml from annotations
# Removing dataset/icub/Images/wallet/wallet9/MIX/day3/left/00004144.jpg from images
# length of dataset =  136093
#
# torch.Size([3, 480, 640])
#  {'boxes': tensor([[362., 196., 522., 304.]]), 'labels': tensor([14]), 'area': tensor([17280.]), 'iscrowd': tensor([0]), 'image_id': tensor([96339])}

# %%
dataset.get_details_from_id(96339)
# Out:
# (PosixPath('dataset/icub/Images/ringbinder/ringbinder7/MIX/day3/left/00003509.jpg'),
#  PosixPath('dataset/icub/Annotations_refined/ringbinder/ringbinder7/MIX/day3/left/00003509.xml'),
#  tensor([[[ 34,  36,  39,  ...,  66,  66,  66],
#           [ 35,  37,  41,  ...,  66,  66,  66],
#           [ 35,  37,  40,  ...,  66,  66,  66],
#           ...,
#           [ 33,  33,  33,  ...,  81,  79,  78],
#           [ 33,  33,  33,  ...,  82,  80,  79],
#           [ 33,  33,  33,  ...,  82,  81,  80]],
#
#          [[ 21,  23,  26,  ...,  65,  65,  65],
#           [ 22,  24,  28,  ...,  65,  65,  65],
#           [ 24,  26,  29,  ...,  65,  65,  65],
#           ...,
#           [ 35,  35,  35,  ...,  87,  85,  84],
#           [ 35,  35,  35,  ...,  88,  86,  85],
#           [ 35,  35,  35,  ...,  88,  87,  86]],
#
#          [[ 15,  17,  20,  ...,  71,  71,  71],
#           [ 16,  18,  22,  ...,  71,  71,  71],
#           [ 20,  22,  23,  ...,  71,  71,  71],
#           ...,
#           [ 34,  34,  34,  ...,  99,  97,  96],
#           [ 34,  34,  34,  ..., 100,  98,  97],
#           [ 34,  34,  34,  ..., 100,  99,  98]]], dtype=torch.uint8),
#  [[362, 196, 522, 304]],
#  'ringbinder')

# %%
dataset.labels, len(dataset.labels)
# Out:
# (['background',
#   'bodylotion',
#   'book',
#   'cellphone',
#   'flower',
#   'glass',
#   'hairbrush',
#   'hairclip',
#   'mouse',
#   'mug',
#   'ovenglove',
#   'pencilcase',
#   'perfume',
#   'remote',
#   'ringbinder',
#   'soapdispenser',
#   'sodabottle',
#   'sprayer',
#   'squeezer',
#   'sunglasses',
#   'wallet'],
#  21)

# %% [markdown]
# Load the pre-trained faster rcnn network

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn_v2, fasterrcnn_mobilenet_v3_large_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# using mobile net for faster training, while have decent accuracy
model = fasterrcnn_mobilenet_v3_large_fpn()

n_classes = len(dataset.labels)

# get number of input features for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, n_classes)

# %%
from torchinfo import summary

summary(model, input_size=(8, 3, 224, 224))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# FasterRCNN                                              [100, 4]                  --
# ├─GeneralizedRCNNTransform: 1-1                         [8, 3, 800, 800]          --
# ├─BackboneWithFPN: 1-2                                  [8, 256, 13, 13]          --
# │    └─IntermediateLayerGetter: 2-1                     [8, 960, 25, 25]          --
# │    │    └─Conv2dNormActivation: 3-1                   [8, 16, 400, 400]         (432)
# │    │    └─InvertedResidual: 3-2                       [8, 16, 400, 400]         (400)
# │    │    └─InvertedResidual: 3-3                       [8, 24, 200, 200]         (3,136)
# │    │    └─InvertedResidual: 3-4                       [8, 24, 200, 200]         (4,104)
# │    │    └─InvertedResidual: 3-5                       [8, 40, 100, 100]         (9,960)
# │    │    └─InvertedResidual: 3-6                       [8, 40, 100, 100]         (20,432)
# │    │    └─InvertedResidual: 3-7                       [8, 40, 100, 100]         (20,432)
# │    │    └─InvertedResidual: 3-8                       [8, 80, 50, 50]           30,960
# │    │    └─InvertedResidual: 3-9                       [8, 80, 50, 50]           33,800
# │    │    └─InvertedResidual: 3-10                      [8, 80, 50, 50]           31,096
# │    │    └─InvertedResidual: 3-11                      [8, 80, 50, 50]           31,096
# │    │    └─InvertedResidual: 3-12                      [8, 112, 50, 50]          212,280
# │    │    └─InvertedResidual: 3-13                      [8, 112, 50, 50]          383,208
# │    │    └─InvertedResidual: 3-14                      [8, 160, 25, 25]          426,216
# │    │    └─InvertedResidual: 3-15                      [8, 160, 25, 25]          793,200
# │    │    └─InvertedResidual: 3-16                      [8, 160, 25, 25]          793,200
# │    │    └─Conv2dNormActivation: 3-17                  [8, 960, 25, 25]          153,600
# │    └─FeaturePyramidNetwork: 2-2                       [8, 256, 13, 13]          --
# │    │    └─ModuleList: 3-20                            --                        (recursive)
# │    │    └─ModuleList: 3-21                            --                        (recursive)
# │    │    └─ModuleList: 3-20                            --                        (recursive)
# │    │    └─ModuleList: 3-21                            --                        (recursive)
# │    │    └─LastLevelMaxPool: 3-22                      [8, 256, 25, 25]          --
# ├─RegionProposalNetwork: 1-3                            [1000, 4]                 --
# │    └─RPNHead: 2-3                                     [8, 15, 25, 25]           --
# │    │    └─Sequential: 3-23                            [8, 256, 25, 25]          590,080
# │    │    └─Conv2d: 3-24                                [8, 15, 25, 25]           3,855
# │    │    └─Conv2d: 3-25                                [8, 60, 25, 25]           15,420
# │    │    └─Sequential: 3-26                            [8, 256, 25, 25]          (recursive)
# │    │    └─Conv2d: 3-27                                [8, 15, 25, 25]           (recursive)
# │    │    └─Conv2d: 3-28                                [8, 60, 25, 25]           (recursive)
# │    │    └─Sequential: 3-29                            [8, 256, 13, 13]          (recursive)
# │    │    └─Conv2d: 3-30                                [8, 15, 13, 13]           (recursive)
# │    │    └─Conv2d: 3-31                                [8, 60, 13, 13]           (recursive)
# │    └─AnchorGenerator: 2-4                             [21285, 4]                --
# ├─RoIHeads: 1-4                                         [100, 4]                  --
# │    └─MultiScaleRoIAlign: 2-5                          [8000, 256, 7, 7]         --
# │    └─TwoMLPHead: 2-6                                  [8000, 1024]              --
# │    │    └─Linear: 3-32                                [8000, 1024]              12,846,080
# │    │    └─Linear: 3-33                                [8000, 1024]              1,049,600
# │    └─FastRCNNPredictor: 2-7                           [8000, 21]                --
# │    │    └─Linear: 3-34                                [8000, 21]                21,525
# │    │    └─Linear: 3-35                                [8000, 84]                86,100
# =========================================================================================================
# Total params: 19,027,604
# Trainable params: 18,968,708
# Non-trainable params: 58,896
# Total mult-adds (Units.GIGABYTES): 147.98
# =========================================================================================================
# Input size (MB): 4.82
# Forward/backward pass size (MB): 3800.82
# Params size (MB): 76.11
# Estimated Total Size (MB): 3881.74
# =========================================================================================================

# %% [markdown]
# Training

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
from sklearn.model_selection import train_test_split

BATCH_SIZE = 8

def collate_fn(batch):
  return tuple(zip(*batch))

# create train and validation set
train_indices, validation_indices = train_test_split(dataset.train_indices, test_size=0.2, random_state=42)
dataset_train = torch.utils.data.Subset(dataset, train_indices)
dataset_valid = torch.utils.data.Subset(dataset, validation_indices)
dataset_test = torch.utils.data.Subset(dataset, dataset.test_indices)

# create data loaders
data_loader_train = torch.utils.data.DataLoader(
    dataset_train,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn,
)
data_loader_valid = torch.utils.data.DataLoader(
    dataset_valid,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn,
)
data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn,
)

# %%
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): FrozenBatchNorm2d(16, eps=1e-05)
#         (2): Hardswish()
#       )
#       (1): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#             (1): FrozenBatchNorm2d(16, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(16, eps=1e-05)
#           )
#         )
#       )
#       (2): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(64, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#             (1): FrozenBatchNorm2d(64, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(24, eps=1e-05)
#           )
#         )
#       )
#       (3): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(72, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (1): FrozenBatchNorm2d(72, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(24, eps=1e-05)
#           )
#         )
#       )
#       (4): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(72, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#             (1): FrozenBatchNorm2d(72, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(40, eps=1e-05)
#           )
#         )
#       )
#       (5): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(120, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#             (1): FrozenBatchNorm2d(120, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(40, eps=1e-05)
#           )
#         )
#       )
#       (6): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(120, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#             (1): FrozenBatchNorm2d(120, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(40, eps=1e-05)
#           )
#         )
#       )
#       (7): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(240, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): FrozenBatchNorm2d(240, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(80, eps=1e-05)
#           )
#         )
#       )
#       (8): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(200, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#             (1): FrozenBatchNorm2d(200, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(80, eps=1e-05)
#           )
#         )
#       )
#       (9): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(184, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#             (1): FrozenBatchNorm2d(184, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(80, eps=1e-05)
#           )
#         )
#       )
#       (10): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(184, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#             (1): FrozenBatchNorm2d(184, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(80, eps=1e-05)
#           )
#         )
#       )
#       (11): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(480, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): FrozenBatchNorm2d(480, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(112, eps=1e-05)
#           )
#         )
#       )
#       (12): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(672, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): FrozenBatchNorm2d(672, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(112, eps=1e-05)
#           )
#         )
#       )
#       (13): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(672, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): FrozenBatchNorm2d(672, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(160, eps=1e-05)
#           )
#         )
#       )
#       (14): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(960, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): FrozenBatchNorm2d(960, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(160, eps=1e-05)
#           )
#         )
#       )
#       (15): InvertedResidual(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(960, eps=1e-05)
#             (2): Hardswish()
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): FrozenBatchNorm2d(960, eps=1e-05)
#             (2): Hardswish()
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Hardsigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(160, eps=1e-05)
#           )
#         )
#       )
#       (16): Conv2dNormActivation(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): FrozenBatchNorm2d(960, eps=1e-05)
#         (2): Hardswish()
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-1): 2 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 15, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=21, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=84, bias=True)
#     )
#   )
# )

# %%
N_EPOCHS = 3

# construct optimizer
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.AdamW(params, lr=5e-3)
# following the tutorial first. Not sure if this is the best optimizer
optimizer = torch.optim.SGD(params, lr=0.005,
                        momentum=0.9,
                        weight_decay=0.0005)

# construct learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=N_EPOCHS, gamma=0.5)

# %%
from tqdm import tqdm
import matplotlib.pyplot as plt

'''
Function to train the model over one epoch.
'''
def train_one_epoch(model, optimizer, data_loader, device):
  train_loss_list = []

  tqdm_bar = tqdm(data_loader, total=len(data_loader))
  for idx, data in enumerate(tqdm_bar):
    optimizer.zero_grad()
    images, targets = data

    # print(targets)

    images = list(image.to(device) for image in images)
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]  # targets = {'boxes'=tensor, 'labels'=tensor}

    losses = model(images, targets)

    loss = sum(loss for loss in losses.values())
    loss_val = loss.item()
    train_loss_list.append(loss.detach().cpu().numpy())

    loss.backward()
    optimizer.step()

    tqdm_bar.set_description(desc=f"Training Loss: {loss_val:.3f}")

  return train_loss_list

'''
Function to validate the model
'''
def evaluate(model, data_loader_test, device):
    val_loss_list = []

    tqdm_bar = tqdm(data_loader_test, total=len(data_loader_test))

    for i, data in enumerate(tqdm_bar):
        images, targets = data

        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        with torch.no_grad():
            losses = model(images, targets)

        loss = sum(loss for loss in losses.values())
        loss_val = loss.item()
        val_loss_list.append(loss_val)

        tqdm_bar.set_description(desc=f"Validation Loss: {loss:.4f}")
    return val_loss_list

'''
Function to plot training and valdiation losses and save them in `output_dir'
'''
def plot_loss(train_loss, valid_loss):
    figure_1, train_ax = plt.subplots()
    figure_2, valid_ax = plt.subplots()

    train_ax.plot(train_loss, color='blue')
    train_ax.set_xlabel('Iteration')
    train_ax.set_ylabel('Training Loss')

    valid_ax.plot(valid_loss, color='red')
    valid_ax.set_xlabel('Iteration')
    valid_ax.set_ylabel('Validation loss')

    # figure_1.savefig(f"{OUTPUT_DIR}/train_loss.png")
    # figure_2.savefig(f"{OUTPUT_DIR}/valid_loss.png")

# %%
from tqdm import tqdm

loss_dict = {'train_loss': [], 'valid_loss': []}
best_model = None

for epoch in range(N_EPOCHS):
    print("----------Epoch {}----------".format(epoch+1))

    # Train the model for one epoch
    train_loss_list = train_one_epoch(model, optimizer, data_loader_train, device)
    loss_dict['train_loss'].extend(train_loss_list)

    lr_scheduler.step()

    # Run evaluation
    valid_loss_list = evaluate(model, data_loader_valid, device)
    loss_dict['valid_loss'].extend(valid_loss_list)

    # store the best model
    if best_model is None or min(valid_loss_list) < min(loss_dict['valid_loss']):
        best_model = model.state_dict()

    # Svae the model ckpt after every epoch
    # ckpt_file_name = f"{OUTPUT_DIR}/epoch_{epoch+1}_model.pth"
    # torch.save({
    #     'epoch': epoch+1,
    #     'model_state_dict': model.state_dict(),
    #     'optimizer_state_dict': optimizer.state_dict(),
    #     'loss_dict': loss_dict
    # }, ckpt_file_name)
# Out:
# ----------Epoch 1----------
# Training Loss: 0.861: 100%|██████████| 13016/13016 [18:23<00:00, 11.80it/s]
# Validation Loss: 0.6024: 100%|██████████| 3254/3254 [03:40<00:00, 14.73it/s]
# ----------Epoch 2----------
# Training Loss: 0.548: 100%|██████████| 13016/13016 [18:11<00:00, 11.93it/s]
# Validation Loss: 0.6554: 100%|██████████| 3254/3254 [03:46<00:00, 14.37it/s]
# ----------Epoch 3----------
# Training Loss: 0.445: 100%|██████████| 13016/13016 [18:12<00:00, 11.92it/s]
# Validation Loss: 0.4722: 100%|██████████| 3254/3254 [03:51<00:00, 14.03it/s]
